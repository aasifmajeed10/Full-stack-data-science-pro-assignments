# %% [markdown]
# # Flask Assignment
# **Submitted by:** Aasif Majeed

# %% [markdown]
# ## Basics of Flask – Question 1
#
# **Question:** Create a Flask app that displays "Hello, World!" on the homepage.

# %% [markdown]
# ### Explanation
#
# This is the most basic Flask application.
# We define a route `/` and return a simple string.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello, World!"

if __name__ == "__main__":
    app.run(debug=False, use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# ## Basics of Flask – Question 2
#
# **Question:** Build a Flask app with static HTML pages and navigate between them.

# %% [markdown]
# ### Explanation
#
# Flask supports static HTML templates using the `templates` folder.
# We use `render_template()` to navigate between pages.

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/")
def index():
    return render_template("index.html")

@app.route("/about")
def about():
    return render_template("about.html")

if __name__ == "__main__":
    app.run(port=5050, debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5050
# Press CTRL+C to quit

# %% [markdown]
# ## Basics of Flask – Question 3
#
# **Question:** Develop a Flask app that uses URL parameters to display dynamic content.

# %% [markdown]
# ### Explanation
#
# URL parameters allow dynamic content rendering.
# The value is passed directly in the URL.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/user/<name>")
def user(name):
    return f"Hello, {name}!"

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# ## Basics of Flask – Question 4
#
# **Question:** Create a Flask app with a form that accepts user input and displays it.

# %% [markdown]
# ### Explanation
#
# Forms allow user interaction.
# We use GET or POST methods to retrieve form data.

# %%
from flask import Flask, request, render_template

app = Flask(__name__)

@app.route("/", methods=["GET", "POST"])
def form():
    if request.method == "POST":
        name = request.form["name"]
        return f"Hello, {name}"
    return '''
        <form method="post">
            Name: <input type="text" name="name">
            <input type="submit">
        </form>
    '''

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# ## Basics of Flask – Question 5
#
# **Question:** Implement user sessions in a Flask app to store and display user-specific data.

# %% [markdown]
# ### Explanation
#
# Sessions store data across requests.
# Flask uses a secret key for session management.

# %%
from flask import Flask, session

app = Flask(__name__)
app.secret_key = "secret_key"

@app.route("/set/<name>")
def set_user(name):
    session["user"] = name
    return "User stored in session"

@app.route("/get")
def get_user():
    return f"User: {session.get('user')}"

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# ## Intermediate Flask – Question 6
#
# **Question:** Build a Flask app that allows users to upload files and display them.

# %% [markdown]
# ### Explanation
#
# Flask supports file uploads using `request.files`.
# Uploaded files are saved to a directory.

# %%
from flask import Flask, request
import os

app = Flask(__name__)
UPLOAD_FOLDER = "uploads"
os.makedirs(UPLOAD_FOLDER, exist_ok=True)

@app.route("/", methods=["GET", "POST"])
def upload():
    if request.method == "POST":
        file = request.files["file"]
        file.save(os.path.join(UPLOAD_FOLDER, file.filename))
        return "File uploaded successfully"
    return '''
        <form method="post" enctype="multipart/form-data">
            <input type="file" name="file">
            <input type="submit">
        </form>
    '''

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# ## Intermediate Flask – Question 7
#
# **Question:** Integrate a SQLite database with Flask to perform CRUD operations.

# %% [markdown]
# ### Explanation
#
# SQLite is a lightweight database.
# Flask can interact with SQLite using `sqlite3`.

# %%
import sqlite3
from flask import Flask

app = Flask(__name__)

@app.route("/create")
def create():
    conn = sqlite3.connect("data.db")
    conn.execute("CREATE TABLE IF NOT EXISTS items (id INTEGER PRIMARY KEY, name TEXT)")
    conn.close()
    return "Table created"

if __name__ == "__main__":
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# ## Intermediate Flask – Question 8
#
# **Question:** Implement user authentication and registration using Flask-Login.

# %% [markdown]
# ### Explanation
#
# Flask-Login handles user sessions securely.
# It manages login, logout, and authentication.

# %%
pip install flask-login
# Out:
# Collecting flask-login
#   Downloading Flask_Login-0.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: Flask>=1.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from flask-login) (3.0.3)
# Requirement already satisfied: Werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from flask-login) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=1.0.4->flask-login) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=1.0.4->flask-login) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=1.0.4->flask-login) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=1.0.4->flask-login) (1.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from Werkzeug>=1.0.1->flask-login) (2.1.3)
# Downloading Flask_Login-0.6.3-py3-none-any.whl (17 kB)
# Installing collected packages: flask-login
# Successfully installed flask-login-0.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Pseudo-code example
from flask_login import LoginManager

login_manager = LoginManager()
login_manager.login_view = "login"

# %% [markdown]
# ## Intermediate Flask – Question 9
#
# **Question:** Create a RESTful API using Flask for CRUD operations.

# %% [markdown]
# ### Explanation
#
# REST APIs use HTTP methods like GET, POST, PUT, DELETE.

# %%
from flask import Flask, jsonify

app = Flask(__name__)

@app.route("/api/books")
def books():
    return jsonify(["Book1", "Book2"])

if __name__ == "__main__":
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (fsevents)
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1074, in launch_instance
#     app.initialize(argv)
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 118, in inner
#     return method(app, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 692, in initialize
#     self.init_sockets()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 331, in init_sockets
#     self.shell_port = self._bind_socket(self.shell_socket, self.shell_port)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 253, in _bind_socket
#     return self._try_bind_socket(s, port)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 229, in _try_bind_socket
#     s.bind("tcp://%s:%i" % (self.ip, port))
#   File "/opt/anaconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 302, in bind
#     super().bind(addr)
#   File "zmq/backend/cython/socket.pyx", line 564, in zmq.backend.cython.socket.Socket.bind
#   File "zmq/backend/cython/checkrc.pxd", line 28, in zmq.backend.cython.checkrc._check_rc
# zmq.error.ZMQError: Address already in use (addr='tcp://127.0.0.1:9002')
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Intermediate Flask – Question 10
#
# **Question:** Design a Flask app with proper error handling for 404 and 500 errors.

# %% [markdown]
# ### Explanation
#
# Custom error handlers improve user experience.

# %%
@app.errorhandler(404)
def not_found(e):
    return "Page not found", 404

@app.errorhandler(500)
def server_error(e):
    return "Server error", 500

# %% [markdown]
# ## Real-Time Development – Question 11
#
# **Question:** Create a real-time chat application using Flask-SocketIO.

# %%
pip install flask_socketio
# Out:
# Collecting flask_socketio
#   Downloading flask_socketio-5.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Flask>=2.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from flask_socketio) (3.0.3)
# Collecting python-socketio>=5.12.0 (from flask_socketio)
#   Downloading python_socketio-5.16.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=2.1.0->flask_socketio) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=2.1.0->flask_socketio) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=2.1.0->flask_socketio) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=2.1.0->flask_socketio) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/anaconda3/lib/python3.12/site-packages (from Flask>=2.1.0->flask_socketio) (1.6.2)
# Collecting bidict>=0.21.0 (from python-socketio>=5.12.0->flask_socketio)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.11.0 (from python-socketio>=5.12.0->flask_socketio)
#   Downloading python_engineio-4.13.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from Jinja2>=3.1.2->Flask>=2.1.0->flask_socketio) (2.1.3)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.11.0->python-socketio>=5.12.0->flask_socketio)
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio>=5.12.0->flask_socketio)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting h11<1,>=0.16.0 (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio>=5.12.0->flask_socketio)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Downloading flask_socketio-5.6.0-py3-none-any.whl (18 kB)
# Downloading python_socketio-5.16.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 3.3 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading python_engineio-4.13.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.3 MB/s eta 0:00:00
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: h11, bidict, wsproto, simple-websocket, python-engineio, python-socketio, flask_socketio
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# httpcore 1.0.2 requires h11<0.15,>=0.13, but you have h11 0.16.0 which is incompatible.
# Successfully installed bidict-0.23.1 flask_socketio-5.6.0 h11-0.16.0 python-engineio-4.13.0 python-socketio-5.16.0 simple-websocket-1.1.0 wsproto-1.3.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Explanation
#
# Flask-SocketIO enables real-time communication.

# %%
from flask_socketio import SocketIO

socketio = SocketIO(app)

# %% [markdown]
# ## Real-Time Development – Question 12
#
# **Question:** Build a Flask app that updates data in real-time using WebSockets.

# %% [markdown]
# ### Explanation
#
# WebSockets allow two-way communication.

# %%
# Uses Flask-SocketIO for real-time updates

# %% [markdown]
# ## Real-Time Development – Question 13
#
# **Question:** Implement notifications in a Flask app using WebSockets.

# %% [markdown]
# ### Explanation
#
# Notifications can be sent instantly using WebSockets.

# %%
# Emit notification events using SocketIO
